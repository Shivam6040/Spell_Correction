# %% [markdown]
# # Probability-Enhanced Spell Correction with Edit Operations

# %% [markdown]
# # Import Necessary Libraries

# %%
import string
import re
import numpy as np
from collections import Counter
import heapq

# %%
def read_corpus(filename):
    # Open the file with specified filename in read mode, using utf-8 encoding
    with open(filename,'r',encoding='utf-8') as file:
        lines = file.readlines()
        
        words = []
        for word in lines:
            # Use regular expression to find all words (alphanumeric sequences)
            words += re.findall(r'\w+',word.lower())
    return words

corpus = read_corpus(r'big.txt')
len(corpus)
# Out:
# 222663

# %% [markdown]
# # create a vocabulary for unique words

# %%
# Create a set of unique words from the corpus
vocab = set(corpus)
len(vocab)
# Out:
# 17647

# %%
# see how many times words appear in the text file
words_count = Counter(corpus)
words_count
# Out:
# Counter({'the': 14703,
#          'project': 91,
#          'gutenberg': 94,
#          'ebook': 10,
#          'of': 6742,
#          'moby': 90,
#          'dick': 90,
#          'or': 797,
#          'whale': 1230,
#          'by': 1222,
#          'herman': 4,
#          'melville': 4,
#          'this': 1439,
#          'is': 1751,
#          'for': 1644,
#          'use': 49,
#          'anyone': 6,
#          'anywhere': 16,
#          'at': 1335,
#          'no': 594,
#          'cost': 4,
#          'and': 6517,
#          'with': 1769,
#          'almost': 197,
#          'restrictions': 2,
#          'whatsoever': 7,
#          'you': 958,
#          'may': 255,
#          'copy': 19,
#          'it': 2534,
#          'give': 90,
#          'away': 186,
#          're': 18,
#          'under': 126,
#          'terms': 33,
#          'license': 18,
#          'included': 14,
#          'online': 4,
#          'www': 6,
#          'org': 13,
#          'title': 8,
#          'author': 9,
#          'release': 1,
#          'date': 4,
#          'december': 5,
#          '25': 4,
#          '2008': 1,
#          '2701': 4,
#          'last': 278,
#          'updated': 2,
#          '3': 16,
#          '2017': 1,
#          'language': 7,
#          'english': 49,
#          'character': 15,
#          'set': 85,
#          'encoding': 1,
#          'utf': 1,
#          '8': 7,
#          'start': 37,
#          'produced': 9,
#          'daniel': 4,
#          'lazarus': 7,
#          'jonesey': 2,
#          'david': 2,
#          'widger': 2,
#          'contents': 8,
#          'etymology': 2,
#          'extracts': 7,
#          'supplied': 13,
#          'a': 4799,
#          'sub': 9,
#          'librarian': 2,
#          'chapter': 308,
#          '1': 49,
#          'loomings': 2,
#          '2': 7,
#          'carpet': 9,
#          'bag': 23,
#          'spouter': 8,
#          'inn': 17,
#          '4': 9,
#          'counterpane': 8,
#          '5': 7,
#          'breakfast': 15,
#          '6': 4,
#          'street': 14,
#          '7': 7,
#          'chapel': 11,
#          'pulpit': 17,
#          '9': 5,
#          'sermon': 5,
#          '10': 5,
#          'bosom': 9,
#          'friend': 27,
#          '11': 2,
#          'nightgown': 2,
#          '12': 2,
#          'biographical': 2,
#          '13': 4,
#          'wheelbarrow': 4,
#          '14': 2,
#          'nantucket': 94,
#          '15': 2,
#          'chowder': 10,
#          '16': 2,
#          'ship': 519,
#          '17': 2,
#          'ramadan': 12,
#          '18': 2,
#          'his': 2530,
#          'mark': 56,
#          '19': 2,
#          'prophet': 17,
#          '20': 5,
#          'all': 1544,
#          'astir': 4,
#          '21': 2,
#          'going': 90,
#          'aboard': 22,
#          '22': 2,
#          'merry': 14,
#          'christmas': 6,
#          '23': 2,
#          'lee': 21,
#          'shore': 26,
#          '24': 2,
#          'advocate': 4,
#          'postscript': 2,
#          '26': 2,
#          'knights': 6,
#          'squires': 4,
#          '27': 2,
#          '28': 2,
#          'ahab': 512,
#          '29': 2,
#          'enter': 11,
#          'to': 4707,
#          'him': 1065,
#          'stubb': 259,
#          '30': 4,
#          'pipe': 42,
#          '31': 2,
#          'queen': 18,
#          'mab': 2,
#          '32': 2,
#          'cetology': 11,
#          '33': 2,
#          'specksnyder': 4,
#          '34': 2,
#          'cabin': 87,
#          'table': 38,
#          '35': 2,
#          'mast': 130,
#          'head': 348,
#          '36': 2,
#          'quarter': 48,
#          'deck': 199,
#          '37': 2,
#          'sunset': 10,
#          '38': 2,
#          'dusk': 3,
#          '39': 2,
#          'first': 239,
#          'night': 152,
#          'watch': 61,
#          '40': 3,
#          'midnight': 30,
#          'forecastle': 38,
#          '41': 2,
#          '42': 2,
#          'whiteness': 28,
#          '43': 2,
#          'hark': 17,
#          '44': 2,
#          'chart': 8,
#          '45': 3,
#          'affidavit': 3,
#          '46': 2,
#          'surmises': 4,
#          '47': 2,
#          'mat': 13,
#          'maker': 5,
#          '48': 2,
#          'lowering': 19,
#          '49': 2,
#          'hyena': 4,
#          '50': 3,
#          's': 1819,
#          'boat': 334,
#          'crew': 141,
#          'fedallah': 28,
#          '51': 2,
#          'spirit': 19,
#          'spout': 61,
#          '52': 2,
#          'albatross': 10,
#          '53': 2,
#          'gam': 6,
#          '54': 2,
#          'town': 36,
#          'ho': 32,
#          'story': 51,
#          '55': 2,
#          'monstrous': 12,
#          'pictures': 19,
#          'whales': 271,
#          '56': 2,
#          'less': 54,
#          'erroneous': 2,
#          'true': 88,
#          'whaling': 132,
#          'scenes': 12,
#          '57': 2,
#          'in': 4238,
#          'paint': 7,
#          'teeth': 50,
#          'wood': 37,
#          'sheet': 9,
#          'iron': 88,
#          'stone': 20,
#          'mountains': 14,
#          'stars': 14,
#          '58': 2,
#          'brit': 9,
#          '59': 2,
#          'squid': 8,
#          '60': 4,
#          'line': 160,
#          '61': 2,
#          'kills': 3,
#          '62': 2,
#          'dart': 26,
#          '63': 2,
#          'crotch': 11,
#          '64': 3,
#          'supper': 31,
#          '65': 2,
#          'as': 1752,
#          'dish': 11,
#          '66': 2,
#          'shark': 31,
#          'massacre': 3,
#          '67': 2,
#          'cutting': 38,
#          '68': 2,
#          'blanket': 14,
#          '69': 2,
#          'funeral': 6,
#          '70': 2,
#          'sphynx': 3,
#          '71': 2,
#          'jeroboam': 11,
#          '72': 3,
#          'monkey': 17,
#          'rope': 60,
#          '73': 2,
#          'flask': 109,
#          'kill': 34,
#          'right': 155,
#          'then': 630,
#          'have': 774,
#          'talk': 26,
#          'over': 410,
#          '74': 2,
#          'sperm': 242,
#          'contrasted': 4,
#          'view': 50,
#          '75': 2,
#          '76': 2,
#          'battering': 7,
#          'ram': 8,
#          '77': 2,
#          'great': 307,
#          'heidelburgh': 9,
#          'tun': 15,
#          '78': 2,
#          'cistern': 5,
#          'buckets': 6,
#          '79': 2,
#          'prairie': 13,
#          '80': 2,
#          'nut': 5,
#          '81': 2,
#          'pequod': 177,
#          'meets': 14,
#          'virgin': 12,
#          '82': 2,
#          'honor': 25,
#          'glory': 19,
#          '83': 2,
#          'jonah': 85,
#          'historically': 2,
#          'regarded': 25,
#          '84': 2,
#          'pitchpoling': 7,
#          '85': 2,
#          'fountain': 10,
#          '86': 2,
#          'tail': 81,
#          '87': 2,
#          'grand': 54,
#          'armada': 2,
#          '88': 2,
#          'schools': 9,
#          'schoolmasters': 3,
#          '89': 2,
#          'fast': 64,
#          'fish': 169,
#          'loose': 37,
#          '90': 4,
#          'heads': 87,
#          'tails': 8,
#          '91': 2,
#          'rose': 35,
#          'bud': 6,
#          '92': 2,
#          'ambergris': 14,
#          '93': 2,
#          'castaway': 5,
#          '94': 2,
#          'squeeze': 10,
#          'hand': 215,
#          '95': 2,
#          'cassock': 3,
#          '96': 2,
#          'try': 55,
#          'works': 64,
#          '97': 2,
#          'lamp': 30,
#          '98': 2,
#          'stowing': 3,
#          'down': 379,
#          'clearing': 6,
#          'up': 526,
#          '99': 2,
#          'doubloon': 21,
#          '100': 4,
#          'leg': 91,
#          'arm': 90,
#          '101': 2,
#          'decanter': 3,
#          '102': 2,
#          'bower': 4,
#          'arsacides': 4,
#          '103': 2,
#          'measurement': 4,
#          'skeleton': 35,
#          '104': 2,
#          'fossil': 5,
#          '105': 2,
#          'does': 98,
#          'magnitude': 23,
#          'diminish': 5,
#          'will': 399,
#          'he': 1896,
#          'perish': 5,
#          '106': 2,
#          '107': 2,
#          'carpenter': 50,
#          '108': 2,
#          '109': 2,
#          'starbuck': 199,
#          '110': 2,
#          'queequeg': 253,
#          'coffin': 53,
#          '111': 2,
#          'pacific': 35,
#          '112': 2,
#          'blacksmith': 22,
#          '113': 2,
#          'forge': 13,
#          '114': 2,
#          'gilder': 2,
#          '115': 2,
#          'bachelor': 9,
#          '116': 2,
#          'dying': 15,
#          '117': 2,
#          '118': 2,
#          'quadrant': 9,
#          '119': 2,
#          'candles': 10,
#          '120': 2,
#          'towards': 115,
#          'end': 103,
#          '121': 2,
#          'bulwarks': 38,
#          '122': 2,
#          'aloft': 63,
#          'thunder': 32,
#          'lightning': 28,
#          '123': 2,
#          'musket': 9,
#          '124': 2,
#          'needle': 12,
#          '125': 2,
#          'log': 23,
#          '126': 2,
#          'life': 175,
#          'buoy': 14,
#          '127': 2,
#          '128': 2,
#          'rachel': 7,
#          '129': 2,
#          '130': 2,
#          'hat': 41,
#          '131': 2,
#          'delight': 19,
#          '132': 2,
#          'symphony': 2,
#          '133': 2,
#          'chase': 62,
#          'day': 179,
#          '134': 2,
#          'second': 62,
#          '135': 2,
#          'third': 34,
#          'epilogue': 2,
#          'original': 23,
#          'transcriber': 1,
#          'notes': 4,
#          'text': 6,
#          'combination': 2,
#          'etexts': 1,
#          'one': 924,
#          'from': 1104,
#          'now': 786,
#          'defunct': 2,
#          'eris': 1,
#          'virginia': 6,
#          'tech': 2,
#          'archives': 1,
#          'proofreaders': 1,
#          'version': 6,
#          'are': 618,
#          'indebted': 2,
#          'university': 1,
#          'adelaide': 1,
#          'library': 3,
#          'preserving': 4,
#          'resulting': 3,
#          'etext': 1,
#          'was': 1646,
#          'compared': 9,
#          'public': 15,
#          'domain': 9,
#          'hard': 84,
#          'late': 30,
#          'consumptive': 1,
#          'usher': 2,
#          'grammar': 2,
#          'school': 10,
#          'pale': 19,
#          'threadbare': 1,
#          'coat': 28,
#          'heart': 91,
#          'body': 110,
#          'brain': 37,
#          'i': 2120,
#          'see': 275,
#          'ever': 206,
#          'dusting': 2,
#          'old': 452,
#          'lexicons': 1,
#          'grammars': 2,
#          'queer': 44,
#          'handkerchief': 5,
#          'mockingly': 1,
#          'embellished': 3,
#          'gay': 21,
#          'flags': 1,
#          'known': 80,
#          'nations': 12,
#          'world': 176,
#          'loved': 3,
#          'dust': 10,
#          'somehow': 44,
#          'mildly': 10,
#          'reminded': 4,
#          'mortality': 1,
#          'while': 246,
#          'take': 137,
#          'others': 40,
#          'teach': 5,
#          'them': 474,
#          'what': 617,
#          'name': 70,
#          'be': 1063,
#          'called': 116,
#          'our': 211,
#          'tongue': 11,
#          'leaving': 38,
#          'out': 537,
#          'through': 235,
#          'ignorance': 11,
#          'letter': 16,
#          'h': 3,
#          'which': 655,
#          'alone': 42,
#          'maketh': 5,
#          'signification': 1,
#          'word': 77,
#          'deliver': 3,
#          'that': 3081,
#          'not': 1173,
#          '_hackluyt': 1,
#          '_': 49,
#          'sw': 1,
#          'dan': 7,
#          '_hval_': 1,
#          'animal': 16,
#          'named': 12,
#          'roundness': 1,
#          'rolling': 35,
#          '_hvalt_': 1,
#          'arched': 11,
#          'vaulted': 2,
#          '_webster': 1,
#          'dictionary': 4,
#          'more': 507,
#          'immediately': 17,
#          'dut': 1,
#          'ger': 1,
#          '_wallen_': 1,
#          '_walw': 1,
#          'ian_': 1,
#          'roll': 18,
#          'wallow': 3,
#          '_richardson': 1,
#          'חו': 1,
#          '_hebrew_': 1,
#          'ϰητος': 1,
#          '_greek_': 1,
#          'cetus': 3,
#          '_latin_': 1,
#          'whœl': 1,
#          '_anglo': 1,
#          'saxon_': 1,
#          'hvalt': 1,
#          '_danish_': 1,
#          'wal': 1,
#          '_dutch_': 1,
#          'hwal': 1,
#          '_swedish_': 1,
#          '_icelandic_': 1,
#          '_english_': 1,
#          'ballena': 1,
#          '_spanish_': 1,
#          'pekee': 1,
#          'nuee': 4,
#          '_fegee_': 1,
#          'pehee': 1,
#          '_erromangoan_': 1,
#          'seen': 165,
#          'mere': 42,
#          'painstaking': 1,
#          'burrower': 1,
#          'grub': 2,
#          'worm': 5,
#          'poor': 114,
#          'devil': 55,
#          'appears': 8,
#          'gone': 59,
#          'long': 332,
#          'vaticans': 1,
#          'stalls': 1,
#          'earth': 46,
#          'picking': 4,
#          'whatever': 46,
#          'random': 5,
#          'allusions': 7,
#          'could': 217,
#          'anyways': 2,
#          'find': 56,
#          'any': 364,
#          'book': 60,
#          'sacred': 10,
#          'profane': 5,
#          'therefore': 67,
#          'must': 293,
#          'every': 232,
#          'case': 72,
#          'least': 76,
#          'higgledy': 1,
#          'piggledy': 1,
#          'statements': 5,
#          'however': 96,
#          'authentic': 3,
#          'these': 405,
#          'veritable': 4,
#          'gospel': 2,
#          'far': 165,
#          'touching': 46,
#          'ancient': 28,
#          'authors': 4,
#          'generally': 31,
#          'well': 230,
#          'poets': 3,
#          'here': 320,
#          'appearing': 4,
#          'solely': 6,
#          'valuable': 11,
#          'entertaining': 2,
#          'affording': 2,
#          'glancing': 14,
#          'bird': 17,
#          'eye': 88,
#          'has': 293,
#          'been': 415,
#          'promiscuously': 1,
#          'said': 305,
#          'thought': 150,
#          'fancied': 9,
#          'sung': 2,
#          'leviathan': 95,
#          'many': 168,
#          'generations': 8,
#          'including': 16,
#          'own': 205,
#          'so': 1066,
#          'fare': 10,
#          'thee': 131,
#          'whose': 87,
#          'commentator': 1,
#          'am': 90,
#          'thou': 271,
#          'belongest': 1,
#          'hopeless': 8,
#          'sallow': 1,
#          'tribe': 9,
#          'wine': 12,
#          'warm': 24,
#          'whom': 45,
#          'even': 193,
#          'sherry': 1,
#          'would': 432,
#          'too': 185,
#          'rosy': 2,
#          'strong': 36,
#          'but': 1823,
#          'sometimes': 87,
#          'loves': 1,
#          'sit': 15,
#          'feel': 57,
#          'devilish': 9,
#          'grow': 24,
#          'convivial': 4,
#          'upon': 568,
#          'tears': 6,
#          'say': 244,
#          'bluntly': 1,
#          'full': 136,
#          'eyes': 156,
#          'empty': 22,
#          'glasses': 10,
#          'altogether': 29,
#          'unpleasant': 3,
#          'sadness': 2,
#          'subs': 1,
#          'how': 258,
#          'much': 224,
#          'pains': 15,
#          'ye': 472,
#          'please': 16,
#          'shall': 97,
#          'go': 193,
#          'thankless': 1,
#          'clear': 41,
#          'hampton': 1,
#          'court': 2,
#          'tuileries': 3,
#          'gulp': 2,
#          'your': 257,
#          'hie': 1,
#          'royal': 28,
#          'hearts': 29,
#          'friends': 17,
#          'who': 366,
#          'before': 301,
#          'seven': 16,
#          'storied': 4,
#          'heavens': 17,
#          'making': 46,
#          'refugees': 1,
#          'pampered': 1,
#          'gabriel': 20,
#          'michael': 3,
#          'raphael': 1,
#          'against': 135,
#          'coming': 54,
#          'strike': 32,
#          'splintered': 7,
#          'together': 64,
#          'there': 865,
#          'unsplinterable': 1,
#          'god': 153,
#          'created': 9,
#          '_genesis_': 1,
#          'path': 10,
#          'shine': 3,
#          'after': 270,
#          'think': 122,
#          'deep': 70,
#          'hoary': 2,
#          '_job_': 1,
#          'lord': 65,
#          'had': 779,
#          'prepared': 12,
#          'swallow': 11,
#          '_jonah_': 1,
#          'ships': 88,
#          'hast': 29,
#          'made': 178,
#          'play': 29,
#          'therein': 6,
#          '_psalms_': 1,
#          'sore': 3,
#          'sword': 25,
#          'punish': 1,
#          'piercing': 4,
#          'serpent': 4,
#          'crooked': 8,
#          'slay': 4,
#          'dragon': 6,
#          'sea': 455,
#          '_isaiah_': 1,
#          'thing': 188,
#          'soever': 1,
#          'besides': 50,
#          'cometh': 1,
#          'within': 83,
#          'chaos': 4,
#          'monster': 49,
#          'mouth': 61,
#          'beast': 4,
#          'goes': 55,
#          'incontinently': 1,
#          'foul': 11,
#          'perisheth': 1,
#          'bottomless': 7,
#          'gulf': 6,
#          'paunch': 2,
#          '_holland': 2,
#          'plutarch': 1,
#          'morals_': 1,
#          'indian': 57,
#          'breedeth': 1,
#          'most': 285,
#          'biggest': 2,
#          'fishes': 5,
#          'among': 167,
#          'whirlpooles': 1,
#          'balaene': 1,
#          'length': 78,
#          'four': 74,
#          'acres': 3,
#          'arpens': 1,
#          'land': 80,
#          'pliny_': 1,
#          'scarcely': 9,
#          'we': 469,
#          'proceeded': 6,
#          'two': 296,
#          'days': 86,
#          'on': 1073,
#          'when': 607,
#          'about': 318,
#          'sunrise': 11,
#          'other': 430,
#          'monsters': 9,
#          'appeared': 10,
#          'former': 20,
#          'size': 12,
#          'came': 130,
#          'us': 229,
#          'open': 76,
#          'mouthed': 5,
#          'raising': 5,
#          'waves': 48,
#          'sides': 28,
#          'beating': 11,
#          'into': 523,
#          'foam': 19,
#          '_tooke': 1,
#          'lucian_': 1,
#          '_the': 12,
#          'history_': 1,
#          'visited': 7,
#          'country': 27,
#          'also': 93,
#          'catching': 7,
#          'horse': 27,
#          'bones': 49,
#          'very': 323,
#          'value': 6,
#          'their': 620,
#          'brought': 38,
#          'some': 619,
#          'king': 63,
#          'best': 66,
#          'were': 683,
#          'catched': 1,
#          'forty': 33,
#          'eight': 27,
#          'fifty': 33,
#          'yards': 27,
#          'six': 31,
#          'killed': 35,
#          'sixty': 17,
#          '_other': 1,
#          'verbal': 2,
#          'narrative': 9,
#          'taken': 51,
#          'alfred': 2,
#          'd': 75,
#          '890': 1,
#          'whereas': 18,
#          'things': 134,
#          'whether': 91,
#          'vessel': 55,
#          'dreadful': 6,
#          'lost': 47,
#          'swallowed': 13,
#          'gudgeon': 1,
#          'retires': 1,
#          'security': 3,
#          'sleeps': 7,
#          'montaigne': 1,
#          '_apology': 1,
#          'raimond': 1,
#          'sebond_': 1,
#          'let': 158,
#          'fly': 14,
#          'nick': 2,
#          'me': 629,
#          'if': 501,
#          'described': 9,
#          'noble': 44,
#          'moses': 2,
#          'patient': 6,
#          'job': 14,
#          '_rabelais_': 1,
#          'liver': 4,
#          'cartloads': 1,
#          '_stowe': 1,
#          'annals_': 1,
#          'seas': 87,
#          'seethe': 3,
#          'like': 647,
#          'boiling': 15,
#          'pan': 5,
#          '_lord': 1,
#          'bacon': 1,
#          'psalms_': 1,
#          'bulk': 32,
#          'ork': 1,
#          'received': 31,
#          'nothing': 115,
#          'certain': 91,
#          'they': 668,
#          'exceeding': 12,
#          'fat': 14,
#          'insomuch': 2,
#          'an': 600,
#          'incredible': 9,
#          'quantity': 13,
#          'oil': 90,
#          'extracted': 5,
#          '_ibid_': 3,
#          '_history': 1,
#          'death_': 1,
#          'sovereignest': 1,
#          'parmacetti': 3,
#          'inward': 5,
#          'bruise': 1,
#          '_king': 1,
#          'henry_': 1,
#          '_hamlet_': 1,
#          'secure': 13,
#          'skill': 10,
#          'leach': 1,
#          'art': 41,
#          'mote': 1,
#          'availle': 1,
#          'returne': 1,
#          'againe': 1,
#          'wound': 17,
#          'worker': 1,
#          'lowly': 8,
#          'dinting': 1,
#          'breast': 7,
#          'bred': 9,
#          'restless': 4,
#          'paine': 1,
#          'wounded': 9,
#          'flies': 7,
#          'thro': 1,
#          'maine': 1,
#          'faerie': 1,
#          'queen_': 1,
#          'immense': 16,
#          'motion': 17,
#          'vast': 73,
#          'bodies': 9,
#          'can': 247,
#          'peaceful': 6,
#          'calm': 41,
#          'trouble': 11,
#          'ocean': 79,
#          'till': 123,
#          'boil': 2,
#          '_sir': 4,
#          'william': 4,
#          'davenant': 1,
#          'preface': 1,
#          'gondibert_': 1,
#          'spermacetti': 3,
#          'men': 244,
#          'might': 183,
#          'justly': 3,
#          'doubt': 32,
#          'since': 65,
#          'learned': 25,
#          'hosmannus': 1,
#          'work': 109,
#          'thirty': 28,
#          'years': 97,
#          'saith': 5,
#          'plainly': 39,
#          '_nescio': 1,
#          'quid': 2,
#          'sit_': 1,
#          't': 290,
#          'browne': 6,
#          'sperma': 3,
#          'ceti': 3,
#          'vide': 1,
#          'v': 7,
#          'e': 52,
#          'spencer': 1,
#          'talus': 1,
#          'modern': 18,
#          'flail': 1,
#          'threatens': 1,
#          'ruin': 5,
#          'ponderous': 13,
#          'fixed': 38,
#          'jav': 1,
#          'lins': 1,
#          'side': 208,
#          'wears': 7,
#          'back': 161,
#          'grove': 3,
#          'pikes': 2,
#          '_waller': 1,
#          'battle': 31,
#          'summer': 16,
#          'islands_': 1,
#          'commonwealth': 1,
#          'state': 33,
#          'latin': 4,
#          'civitas': 1,
#          'artificial': 5,
#          'man': 527,
#          '_opening': 1,
#          'sentence': 3,
#          'hobbes': 1,
#          'leviathan_': 1,
#          'silly': 5,
#          'mansoul': 1,
#          'without': 164,
#          'chewing': 1,
#          'sprat': 1,
#          '_pilgrim': 1,
#          'progress_': 1,
#          'hugest': 4,
#          'swim': 21,
#          'stream': 11,
#          '_paradise': 1,
#          'lost_': 1,
#          'living': 73,
#          'creatures': 34,
#          'stretched': 10,
#          'promontory': 5,
#          'swims': 8,
#          'seems': 87,
#          'moving': 15,
#          'gills': 4,
#          'draws': 1,
#          'breath': 18,
#          'spouts': 16,
#          'mighty': 47,
#          'water': 190,
#          'swimming': 30,
#          '_fuller': 1,
#          'holy': 21,
#          'state_': 1,
#          'close': 56,
#          'behind': 50,
#          ...})

# %% [markdown]
# # Calculate Word probability
#
# P(word) = count(word) / N

# %%
total_words_count = float(sum(words_count.values()))

# Create a dictionary of word probabilities by dividing each word count by the total word count
word_probabs = {word:words_count[word] / total_words_count for word in words_count.keys()}

word_probabs['use']
# Out:
# 0.0002200635040397372

# %% [markdown]
# # Autocorrect operations

# %% [markdown]
# # 1. Split Operation:

# %%
def split(word):
#     Return a list of tuples representing all possible splits of the given word
    return [ (word[:i], word[i:])  for i in range(len(word) + 1)]

print(split('why'))
# Out:
# [('', 'why'), ('w', 'hy'), ('wh', 'y'), ('why', '')]

# %% [markdown]
# # 2. Delete Operation:

# %%
def delete(word):
    # Create a list of words by deleting one character from the original word
    return [left + right[1:] for left,right in split(word) if right]
print(delete('why'))
# Out:
# ['hy', 'wy', 'wh']

# %% [markdown]
# # 3. Swap Operation:

# %%
def swap(word):
    # Return a list of words obtained by swapping adjacent characters in the given word
    return [left + right[1] + right[0] + right[2:] for left,right in split(word) if len(right) > 1 ]

print(swap('why'))
# Out:
# ['hwy', 'wyh']

# %% [markdown]
# # 4. replace Operation:

# %%
def replace(word):
    # Return a list of words by replacing the center character with each lowercase letter
    return [left + center + right[1:] for left, right in split(word) if right for center in string.ascii_lowercase]

print(replace('why'))
# Out:
# ['ahy', 'bhy', 'chy', 'dhy', 'ehy', 'fhy', 'ghy', 'hhy', 'ihy', 'jhy', 'khy', 'lhy', 'mhy', 'nhy', 'ohy', 'phy', 'qhy', 'rhy', 'shy', 'thy', 'uhy', 'vhy', 'why', 'xhy', 'yhy', 'zhy', 'way', 'wby', 'wcy', 'wdy', 'wey', 'wfy', 'wgy', 'why', 'wiy', 'wjy', 'wky', 'wly', 'wmy', 'wny', 'woy', 'wpy', 'wqy', 'wry', 'wsy', 'wty', 'wuy', 'wvy', 'wwy', 'wxy', 'wyy', 'wzy', 'wha', 'whb', 'whc', 'whd', 'whe', 'whf', 'whg', 'whh', 'whi', 'whj', 'whk', 'whl', 'whm', 'whn', 'who', 'whp', 'whq', 'whr', 'whs', 'wht', 'whu', 'whv', 'whw', 'whx', 'why', 'whz']

# %% [markdown]
# # 5. Insert Opearations

# %%
def insert(word):
    # Return a list of words generated by inserting each letter of the alphabet at every possible position in the given word
    return [left + center + right[1:] for left, right in split(word) for center in string.ascii_lowercase]

print(replace('project'))
# Out:
# ['aroject', 'broject', 'croject', 'droject', 'eroject', 'froject', 'groject', 'hroject', 'iroject', 'jroject', 'kroject', 'lroject', 'mroject', 'nroject', 'oroject', 'project', 'qroject', 'rroject', 'sroject', 'troject', 'uroject', 'vroject', 'wroject', 'xroject', 'yroject', 'zroject', 'paoject', 'pboject', 'pcoject', 'pdoject', 'peoject', 'pfoject', 'pgoject', 'phoject', 'pioject', 'pjoject', 'pkoject', 'ploject', 'pmoject', 'pnoject', 'pooject', 'ppoject', 'pqoject', 'project', 'psoject', 'ptoject', 'puoject', 'pvoject', 'pwoject', 'pxoject', 'pyoject', 'pzoject', 'praject', 'prbject', 'prcject', 'prdject', 'preject', 'prfject', 'prgject', 'prhject', 'priject', 'prjject', 'prkject', 'prlject', 'prmject', 'prnject', 'project', 'prpject', 'prqject', 'prrject', 'prsject', 'prtject', 'pruject', 'prvject', 'prwject', 'prxject', 'pryject', 'przject', 'proaect', 'probect', 'procect', 'prodect', 'proeect', 'profect', 'progect', 'prohect', 'proiect', 'project', 'prokect', 'prolect', 'promect', 'pronect', 'prooect', 'propect', 'proqect', 'prorect', 'prosect', 'protect', 'prouect', 'provect', 'prowect', 'proxect', 'proyect', 'prozect', 'projact', 'projbct', 'projcct', 'projdct', 'project', 'projfct', 'projgct', 'projhct', 'projict', 'projjct', 'projkct', 'projlct', 'projmct', 'projnct', 'projoct', 'projpct', 'projqct', 'projrct', 'projsct', 'projtct', 'projuct', 'projvct', 'projwct', 'projxct', 'projyct', 'projzct', 'projeat', 'projebt', 'project', 'projedt', 'projeet', 'projeft', 'projegt', 'projeht', 'projeit', 'projejt', 'projekt', 'projelt', 'projemt', 'projent', 'projeot', 'projept', 'projeqt', 'projert', 'projest', 'projett', 'projeut', 'projevt', 'projewt', 'projext', 'projeyt', 'projezt', 'projeca', 'projecb', 'projecc', 'projecd', 'projece', 'projecf', 'projecg', 'projech', 'projeci', 'projecj', 'projeck', 'projecl', 'projecm', 'projecn', 'projeco', 'projecp', 'projecq', 'projecr', 'projecs', 'project', 'projecu', 'projecv', 'projecw', 'projecx', 'projecy', 'projecz']

# %% [markdown]
# # Implement edit distance algorithm

# %%
def level_one_edits(word):
    # Combine sets of words generated by delete, swap, replace, and insert operations
    return set((delete(word) + swap(word) + replace(word) + insert(word)))

print(level_one_edits('load'))
# Out:
# {'lbad', 'loar', 'ioad', 'loadb', 'woad', 'foad', 'loab', 'loax', 'loda', 'hoad', 'laad', 'loada', 'lkad', 'logd', 'loadp', 'loadz', 'loak', 'lond', 'lsad', 'loadk', 'xoad', 'lohd', 'lqad', 'loaz', 'loaa', 'coad', 'loads', 'loadf', 'olad', 'moad', 'loadh', 'lod', 'ltad', 'loaj', 'loam', 'loaq', 'loade', 'loaf', 'lead', 'llad', 'soad', 'loai', 'loal', 'loadr', 'loaw', 'loah', 'loao', 'koad', 'joad', 'lcad', 'lgad', 'lmad', 'loadl', 'lad', 'loed', 'lopd', 'qoad', 'lxad', 'loadg', 'road', 'lrad', 'lwad', 'load', 'loadm', 'luad', 'locd', 'loadw', 'lojd', 'goad', 'eoad', 'lomd', 'loadc', 'doad', 'lofd', 'loav', 'aoad', 'loadn', 'lord', 'lowd', 'loae', 'ldad', 'losd', 'yoad', 'loac', 'ooad', 'loadq', 'loady', 'loap', 'loay', 'loas', 'loxd', 'lfad', 'lyad', 'poad', 'voad', 'boad', 'lvad', 'lozd', 'loadd', 'loadx', 'lovd', 'loyd', 'oad', 'ljad', 'loid', 'lpad', 'loa', 'loadt', 'loadv', 'loag', 'laod', 'uoad', 'loan', 'toad', 'loadj', 'liad', 'loud', 'lokd', 'loadi', 'loadu', 'noad', 'loau', 'loqd', 'loado', 'lzad', 'lood', 'lold', 'lotd', 'loat', 'lodd', 'zoad', 'lobd', 'lnad', 'lhad'}

# %%
def level_two_edits(word):
    # Return a set of level-two edits for the given word
    # Level-two edits are generated by applying level-one edits to each level-one edit of the original word
    return set(e2  for e1 in level_one_edits(word) for e2 in level_one_edits(e1))

# %%
print(level_two_edits('cut'))
# Out:
# {'tit', 'dutf', 'cxx', 'ug', 'cptu', 'citf', 'cuthv', 'wpt', 'muy', 'clh', 'wutu', 'fuy', 'kpt', 'cudt', 'cuwl', 'cutvv', 'ht', 'cutmg', 'cvx', 'buj', 'chx', 'cmtt', 'cutui', 'cltf', 'eqt', 'cukf', 'bua', 'cvtj', 'cas', 'czc', 'nuq', 'cutyp', 'cutcg', 'wutl', 'cueu', 'ucp', 'jute', 'cutuo', 'cmr', 'cyk', 'rue', 'cjh', 'qua', 'cbq', 'cutxm', 'cuay', 'rua', 'cutyy', 'hutc', 'luz', 'cutnb', 'cotp', 'hutf', 'cutbd', 'cqp', 'cltu', 'xzt', 'kutk', 'iur', 'cumi', 'cutug', 'cbi', 'cumt', 'zutq', 'cufp', 'jct', 'avt', 'cugh', 'luth', 'ctu', 'cush', 'rut', 'quto', 'gutb', 'cbo', 'cctl', 'xua', 'ckc', 'cqt', 'uctd', 'cufa', 'oct', 'lux', 'tbt', 'xpt', 'ucz', 'jkt', 'cutjz', 'ckt', 'tuc', 'cutpm', 'cutbr', 'cwtt', 'curv', 'cusk', 'ckf', 'dtu', 'cutuf', 'bur', 'eot', 'cett', 'caf', 'cko', 'chth', 'cutsx', 'cya', 'utw', 'rutp', 'cee', 'due', 'curn', 'cutq', 'iute', 'uutr', 'cxtc', 'cbto', 'cutbi', 'cujp', 'cutsg', 'chty', 'tlt', 'iutc', 'cytf', 'vdt', 'vit', 'ceg', 'clb', 'cutdk', 'cwy', 'cztb', 'autz', 'jgt', 'catf', 'clk', 'cro', 'cuton', 'tvt', 'ztu', 'buv', 'ckd', 'ryt', 'cukh', 'cutjx', 'auta', 'ukt', 'utt', 'cyr', 'cutom', 'cutgk', 'kuk', 'cutfw', 'cutvw', 'cuim', 'cgtu', 'cuto', 'cpb', 'yht', 'got', 'cxtz', 'qot', 'xuo', 'rnt', 'catg', 'cuma', 'cutek', 'hkt', 'gutw', 'wuti', 'ret', 'tutn', 'cfu', 'cwtc', 'euto', 'cuyx', 'eutn', 'cst', 'iutk', 'cxtd', 'ot', 'cutaz', 'xutk', 'lgt', 'cutkp', 'xutb', 'nuta', 'cuqv', 'eui', 'cha', 'bnt', 'crs', 'cdm', 'cunz', 'lutt', 'cunj', 'catu', 'cutdb', 'cwq', 'let', 'lutv', 'cuuq', 'cuuy', 'wue', 'pyt', 'uty', 'eutf', 'futo', 'cnty', 'quti', 'cuqb', 'wutn', 'cutyz', 'ceta', 'tft', 'ctuc', 'zutv', 'cvtz', 'cumo', 'cetr', 'mpt', 'cutgs', 'sxt', 'nug', 'cuht', 'cudo', 'cua', 'nutp', 'cftg', 'cmtb', 'cttc', 'chtw', 'cumc', 'cusn', 'yuj', 'eutk', 'itt', 'cuxf', 'cub', 'zuw', 'zuy', 'vutx', 'lug', 'cntw', 'cuns', 'sutp', 'cugb', 'csp', 'wua', 'aue', 'mutd', 'clr', 'auy', 'cuja', 'hut', 'chtm', 'czt', 'putr', 'cutmq', 'cktb', 'cuvr', 'futn', 'czti', 'yuc', 'cutzk', 'kct', 'cutvn', 'gutm', 'cvc', 'cuvh', 'outm', 'ruc', 'cuwd', 'gux', 'zmt', 'cntr', 'cxi', 'mui', 'cutro', 'cutih', 'cmtg', 'cpm', 'rutf', 'cutnj', 'cucd', 'mqt', 'csty', 'cdtf', 'cim', 'cix', 'czz', 'cure', 'cutur', 'dutd', 'cutle', 'cnth', 'cjtb', 'cuwm', 'cutml', 'ruta', 'cptb', 'muu', 'ojt', 'autp', 'cntg', 'pug', 'ckp', 'dutp', 'zutk', 'euc', 'cbe', 'huti', 'cuis', 'gur', 'cuwi', 'cuteq', 'cutry', 'cutvt', 'uca', 'hua', 'eutd', 'cury', 'apt', 'cuvv', 'qtt', 'yutw', 'cto', 'wutm', 'ctf', 'cupe', 'cez', 'irt', 'cuph', 'zht', 'cutnx', 'gug', 'fkt', 'cwj', 'curj', 'cuap', 'cbtz', 'cuzr', 'mmt', 'cite', 'cuttt', 'sutk', 'xur', 'nul', 'cuhm', 'oui', 'cutoc', 'cvtk', 'cgtt', 'cusd', 'wuu', 'cuku', 'cvz', 'cktz', 'outk', 'uci', 'ltt', 'uot', 'cik', 'eutb', 'cutd', 'crv', 'chtf', 'obt', 'zyt', 'det', 'cuav', 'guts', 'xuth', 'cumm', 'iat', 'cmti', 'qub', 'cutjs', 'zot', 'cutux', 'czty', 'dutn', 'qutu', 'sutq', 'cutyv', 'cutmn', 'dute', 'cugt', 'cutoz', 'yxt', 'cutgx', 'cutod', 'cupt', 'cutnk', 'quo', 'cutrz', 'ckn', 'ckto', 'gtu', 'crl', 'cott', 'auz', 'cuhf', 'cbtv', 'rug', 'oux', 'cutof', 'cubh', 'cust', 'cjtd', 'cy', 'jutb', 'ctd', 'cctc', 'tuz', 'fht', 'nuty', 'cetz', 'cuwb', 'vuz', 'ctc', 'lud', 'iwt', 'cuet', 'lutp', 'csg', 'cvtn', 'grt', 'dutw', 'crtq', 'kuw', 'up', 'cutqk', 'dur', 'cutum', 'cuten', 'ckw', 'cusc', 'cuteg', 'cutmy', 'cnz', 'cpl', 'wht', 'kuti', 'qutp', 'buts', 'cof', 'cety', 'cutly', 'cufu', 'cuthg', 'cmt', 'cag', 'csth', 'xqt', 'euts', 'cytl', 'tuq', 'cufk', 'xct', 'cntc', 'cutdh', 'quth', 'cuyq', 'cetl', 'cuzb', 'tuo', 'ntu', 'vuts', 'cwts', 'nutc', 'cuny', 'cupj', 'cuyi', 'ciy', 'sux', 'hux', 'cptq', 'cov', 'nutn', 'tat', 'cuyo', 'cetg', 'cutru', 'cuex', 'lun', 'cds', 'cqx', 'cutyq', 'ucv', 'qul', 'ucti', 'cltm', 'iuu', 'cuzl', 'aht', 'kutz', 'auw', 'putw', 'cuvs', 'caz', 'sutw', 'cutun', 'cutfd', 'kyt', 'hmt', 'puj', 'qbt', 'cjk', 'cuttd', 'utm', 'cukw', 'cge', 'qutd', 'ceb', 'cbta', 'cctg', 'cdf', 'cutnm', 'cutip', 'czv',  ...

# %% [markdown]
# #  Function to Autocorrect misspelled word

# %%
def correct_spelling(word, vocab, word_probabs):
    if word in vocab:
        return f"{word} is already correctly spelled"

    # Getting all suggestions
    suggestions = level_one_edits(word) or level_two_edits(word) or [word]

    # Using a priority queue to prioritize suggestions based on word probabilities
    suggestion_heap = []  # Priority queue using a min heap
    for w in suggestions:
        if w in vocab:
            heapq.heappush(suggestion_heap, (word_probabs[w], w))
    if not suggestion_heap:
        return( f"Sorry, no suggestions found for {word}")

    # Extracting and formatting the top suggestions from the priority queue
    top_suggestions = heapq.nlargest(10, suggestion_heap)
    formatted_suggestions = [(w ,f"{prob:.4f}") for prob, w in top_suggestions]

    return formatted_suggestions

# %%
search_word = "losd"
guess = correct_spelling(search_word,vocab,word_probabs)
print(guess)
# Out:
# [('lord', '0.0003'), ('lost', '0.0002'), ('loud', '0.0001'), ('loss', '0.0000'), ('lose', '0.0000'), ('load', '0.0000')]

# %%
def calculate_accuracy(test_data, vocab, word_probabs):
    correct_predictions = 0
    total_predictions = len(test_data)
    print("{:<20} {:<20}".format("Misspelled Word", "Correct Word"))
    print("-" * 40)
    
    for test_word, expected_correction in test_data:
        correction = correct_spelling(test_word, vocab, word_probabs)
        if not isinstance(correction, str):
            # Check if any of the corrections match the expected result
            for correct_word, probability in correction:
                if correct_word == expected_correction:
                    print("{:<20} {:<20}".format(test_word, correct_word))
                    correct_predictions += 1
                    break

    # Calculate accuracy
    accuracy = correct_predictions / total_predictions

    return accuracy


# Create a test data
test_data = [("projetc", "project"), ("anypne", "anyone"), ("accuaracy", "accuracy"), 
             ("losd", "load"), ("likelihopd", "likelihood"), ("languahe", "language")]

# Calculate accuracy
accuracy = calculate_accuracy(test_data, vocab, word_probabs)

# Print the result
print(f"\nAccuracy: {accuracy:.2%}")
# Out:
# Misspelled Word      Correct Word
# ----------------------------------------
# projetc              project
# anypne               anyone
# accuaracy            accuracy
# losd                 load
# languahe             language
#
# Accuracy: 83.33%
